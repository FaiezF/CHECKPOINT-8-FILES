# %%
def file_read(abc):
        txt = open(abc)
        print(txt.read())

file_read('test.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-98eeb7ca4934> in <module>()
#       3         print(txt.read())
#       4
# ----> 5 file_read('test.txt')
#
# <ipython-input-1-98eeb7ca4934> in file_read(abc)
#       1 def file_read(abc):
# ----> 2         txt = open(abc)
#       3         print(txt.read())
#       4
#       5 file_read('test.txt')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

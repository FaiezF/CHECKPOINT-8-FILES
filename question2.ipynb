# %%
a_file = open("file_name.txt")
number_of_lines = n
for i in range(number_of_lines):
  line = a_file.readline()
# Out:
#   File "<ipython-input-1-74fab3a34ca0>", line 3
#     print(line,end=)
#                    ^
# SyntaxError: invalid syntax

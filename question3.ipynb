# %%
a_file = open("example.txt", "r")
EXAMPLE.TXT
line1
line2
line3
line4
line5
line6
line7
line8
line9
line10
lines = a_file.readlines()
last_lines = lines[-5:]

print(last_lines)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-2c5f0582c8de> in <module>()
# ----> 1 a_file = open("example.txt", "r")
#       2 EXAMPLE.TXT
#       3 line1
#       4 line2
#       5 line3
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.txt'
